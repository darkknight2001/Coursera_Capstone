# %% [markdown]
# # The Battle of Neighborhoods (Week 2)

# %% [markdown]
# ## Introduction and definition of the scope of the problem

# %% [markdown]
# Our target audience and stakeholders are companies and individuals who wish to open new restaurant premises on the city of Santa Monica in City Center. However that is not a straightforward process, for reasons I will next explain. The pitfalls are mainly competition, cost of operating a business, cultural differences that exist in some areas, and the demographic makeup of some localities. Thus the clients require an analysis of the local neighbourhoods to understand the scope of the issues. Some types of restaurants are better suited to particular areas.
# The population of the City of Santa Monica, California is an estimated 91,577. Santa Monica is a cosmopolitan city with a broad mixture of Americans and immigrants from other countries. The demographic makeup of the people in the city are of mainly White, African Americans, Hispanic or Latino, and Native Americans. Naturally there is much choice of restaurants, serving both Domestic and foreign foods.
# Santa Monica Demographics
# • White: 75.9% (64.6% non-Hispanic)
# • Black or African American: 4.5%
# • American Indian: 0.3%
# • Asian: 10.2%
# • Pacific Islander: 0.1%
# • Two or more races: 5.9%
# • Hispanic of any race: 15.4%
# Jan 10, 2019
# Since Santa Monica is such a multicultural and eclectic hub, with a large workforce available, the city offers many business opportunities which groups of investors can exploit. The downside is, that since there are many restaurants there already, hence the competition for customers is considerable. Property in the City Center area is also expensive and suffers from being heavily taxed. The cost of trading in Santa Monica, therefore requires to be thoroughly analysed and considered before any new company can be opened. In this analysis we will attempt to find the best location for the new business, by examining what already exists in the chosen area. In particular we will be looking at the City Center area of the city.

# %% [markdown]
# The data that will be used to solve the problem: We will be using Foursquare and geopy data to map top the top venues within the location of Santa Monica’s City Center to indicate what venues already exist in this popular area. We will create a map of the area covering about 5000m.

# %% [markdown]
# ## Methodology
#
# The methodology we have used was to utilize Foursquare to analyse the chosen neighborhood and create a breakdown of businesses types and numbers in the chosen area.  The idea behind this, is that if we know the numbers and types of restaurants and franchises already present there, it will allow us to decide on which type of new restaurant would be the most welcome with the least amount of competition in that type of food.

# %% [markdown]
# ## Discussion
#
# It was found that some types of restuarant and francise where far more common than others.
#
# In particular:
# Starbucks                                                       2
# Moorten Botanical Garden                                        1
# Swiss Donut                                                     1
# ALDI                                                            1
#
#
# Others were less clear, since there are several Mexican or Tex-Mex resturants in the area which the data makes harder to count.  In the main however, business showed a good spread of uniqueness, and where mostly one of a kind in that area.

# %% [markdown]
# ## Conclusion
#
# The area is suited to opening an up-market restaurant, main competition comes from the Mexican resturants and Fast Food.

# %%
import numpy as np # library to handle data in a vectorized manner
import time
import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files
import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# usage: conda-script.py [-h] [-V] command ...
# conda-script.py: error: unrecognized arguments: # uncomment this line if you haven't completed the Foursquare API lab
# Libraries imported.

# %% [markdown]
# ## Neighborhood Candidates
# ## We will be creating gepgraphic coordinates for centroids of our candidate neighborhoods.
# ## First we'll find the latitude & longitude of Santa Monica's popular City Center a likely
# ## contender for siting the new restaurant.

# %%
# Find the geographical coordinates of The Energy Corridor, Houston, TX
address = 'city center, Santa Monica, california'

geolocator = Nominatim(user_agent="myapplication")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of the City Center, Santa Monica, CA are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of the City Center, Santa Monica, CA are 33.7932172, -116.5033811.

# %%
city_center = [latitude, longitude]
print('Coordinate of {}: {}'.format(address, city_center))
city_center
# Out:
# Coordinate of city center, Santa Monica, california: [33.7932172, -116.5033811]
# [33.7932172, -116.5033811]

# %%
neighborhood_latitude=33.7932172
neighborhood_longitude=-116.5033811

# %%
#!pip install folium

import folium

# %%
CLIENT_ID = 'XJ1CNXNT1GL2I3DHVB1LHUY5M4SHBMENB3JKNKMX0B3QILVY' # my Foursquare ID
CLIENT_SECRET = '1A2K4IV2PDT4KQCSDW3JIVUB2IMYK54R0SZVPRPJ1JXV5TBN' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
radius = 500
LIMIT = 100

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: XJ1CNXNT1GL2I3DHVB1LHUY5M4SHBMENB3JKNKMX0B3QILVY
# CLIENT_SECRET:1A2K4IV2PDT4KQCSDW3JIVUB2IMYK54R0SZVPRPJ1JXV5TBN

# %% [markdown]
# ## Get the top 100 venues that are near Santa Monica's City Center. within a radius of 5000 meters

# %%
LIMIT = 100 # limit of number of venues returned by Foursquare API

radius = 5000 # define radius

# create URL
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude, 
    longitude, 
    radius, 
    LIMIT)
url # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=XJ1CNXNT1GL2I3DHVB1LHUY5M4SHBMENB3JKNKMX0B3QILVY&client_secret=1A2K4IV2PDT4KQCSDW3JIVUB2IMYK54R0SZVPRPJ1JXV5TBN&v=20180605&ll=33.7932172,-116.5033811&radius=5000&limit=100'

# %% [markdown]
# Send the GET request and examine the resutls

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '606aaec827744b0450216630'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'},
#     {'name': '$-$$$$', 'key': 'price'}]},
#   'headerLocation': 'Palm Springs',
#   'headerFullLocation': 'Palm Springs',
#   'headerLocationGranularity': 'city',
#   'totalResults': 220,
#   'suggestedBounds': {'ne': {'lat': 33.838217245000045,
#     'lng': -116.44933380136733},
#    'sw': {'lat': 33.748217154999956, 'lng': -116.55742839863267}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c143a0eb7b9c928c813ab37',
#        'name': 'PSYC Spa',
#        'location': {'address': 'Le Parker Meridien',
#         'lat': 33.79555800199492,
#         'lng': -116.50094089596321,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.79555800199492,
#           'lng': -116.50094089596321}],
#         'distance': 344,
#         'postalCode': '92264',
#         'cc': 'US',
#         'city': 'Palm Springs',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['Le Parker Meridien',
#          'Palm Springs, CA 92264',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ed941735',
#          'name': 'Spa',
#          'pluralName': 'Spas',
#          'shortName': 'Spa',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c143a0eb7b9c928c813ab37-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bdf2f6b0ee3a5934f4033b0',
#        'name': "Norma's",
#        'location': {'address': '4200 E Palm Canyon Dr',
#         'lat': 33.79545087834512,
#         'lng': -116.50026908656335,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.79545087834512,
#           'lng': -116.50026908656335}],
#         'distance': 380,
#         'postalCode': '92264',
#         'cc': 'US',
#         'city': 'Palm Springs',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['4200 E Palm Canyon Dr',
#          'Palm Springs, CA 92264',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d143941735',
#          'name': 'Breakfast Spot',
#          'pluralName': 'Breakfast Spots',
#          'shortName': 'Breakfast',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bdf2f6b0ee3a5934f4033b0-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5bdfc810492814002c7aec2e',
#        'name': 'The Parker Palm Springs',
#        'location': {'address': '4200 E Palm Canyon Dr',
#         'lat': 33.795264492818035,
#         'lng': -116.50020412073837,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.795264492818035,
#           'lng': -116.50020412073837}],
#         'distance': 371,
#         'postalCode': '92264',
#         'cc': 'US',
#         'city': 'Palm Springs',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['4200 E Palm Canyon Dr',
#          'Palm Springs, CA 92264',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5bdfc810492814002c7aec2e-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c53364f30f92d7fcf9168b8',
#        'name': 'Lemonade Stand',
#        'location': {'address': '4200 E Palm Canyon Dr',
#         'crossStreet': 'at the Parker Palm Springs',
#         'lat': 33.796288071910745,
#         'lng': -116.5007913677242,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.796288071910745,
#           'lng': -116.5007913677242}],
#         'distance': 417,
#         'postalCode': '92264',
#         'cc': 'US',
#         'city': 'Palm Springs',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['4200 E Palm Canyon Dr (at the Parker Palm Springs)',
#          'Palm Springs, CA 92264',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c53364f30f92d7fcf9168b8-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '58a1496616f000694e663c51',
#        'name': 'Counter Reformation',
#        'location': {'address': '4200 E Palm Canyon Dr',
#         'lat': 33.79536851992258,
#         'lng': -116.50029224522532,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.79536851992258,
#           'lng': -116.50029224522532}],
#         'distance': 372,
#         'postalCode': '92264',
#         'cc': 'US',
#         'city': 'Palm Springs',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['4200 E Palm Canyon Dr',
#          'Palm Springs, CA 92264',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d4941735',
#          'name': 'Speakeasy',
#          'pluralName': 'Speakeasies',
#          'shortName': 'Speakeasy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/secretbar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-58a1496616f000694e663c51-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc4d9dfabf49521bea9c593',
#        'name': "Trader Joe's",
#        'location': {'address': '67720 E Palm Canyon Dr',
#         'crossStreet': 'In Canyon Plaza',
#         'lat': 33.78921849430684,
#         'lng': -116.483059509695,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.78921849430684,
#           'lng': -116.483059509695}],
#         'distance': 1932,
#         'postalCode': '92234',
#         'cc': 'US',
#         'city': 'Cathedral City',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['67720 E Palm Canyon Dr (In Canyon Plaza)',
#          'Cathedral City, CA 92234',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bc4d9dfabf49521bea9c593-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b71a5bcf964a52072532de3',
#        'name': 'T.J. Maxx',
#        'location': {'address': '2465 E Palm Canyon Dr',
#         'lat': 33.7996865,
#         'lng': -116.5201399,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.7996865,
#           'lng': -116.5201399}],
#         'distance': 1709,
#         'postalCode': '92264',
#         'cc': 'US',
#         'city': 'Palm Springs',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['2465 E Palm Canyon Dr',
#          'Palm Springs, CA 92264',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1f6941735',
#          'name': 'Department Store',
#          'pluralName': 'Department Stores',
#          'shortName': 'Department Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/departmentstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b71a5bcf964a52072532de3-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c0027d6f61ea5936d6beb13',
#        'name': 'Chipotle Mexican Grill',
#        'location': {'address': '2465 E Palm Canyon Dr Ste 1110',
#         'crossStreet': 'E. Palm Canyon & Farrell (Smoke Tree)',
#         'lat': 33.80077209644914,
#         'lng': -116.52167565167815,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.80077209644914,
#           'lng': -116.52167565167815},
#          {'label': 'entrance', 'lat': 33.801117, 'lng': -116.521833}],
#         'distance': 1889,
#         'postalCode': '92264',
#         'cc': 'US',
#         'city': 'Palm Springs',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['2465 E Palm Canyon Dr Ste 1110 (E. Palm Canyon & Farrell (Smoke Tree))',
#          'Palm Springs, CA 92264',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c1941735',
#          'name': 'Mexican Restaurant',
#          'pluralName': 'Mexican Restaurants',
#          'shortName': 'Mexican',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c0027d6f61ea5936d6beb13-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad24911f964a520b1e020e3',
#        'name': 'Manhattan In The Desert',
#        'location': {'address': '2665 E Palm Canyon Dr',
#         'crossStreet': 'at Barona Rd',
#         'lat': 33.800954,
#         'lng': -116.518154,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.800954,
#           'lng': -116.518154}],
#         'distance': 1615,
#         'postalCode': '92264',
#         'cc': 'US',
#         'city': 'Palm Springs',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['2665 E Palm Canyon Dr (at Barona Rd)',
#          'Palm Springs, CA 92264',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'shortName': 'Sandwiches',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '343682',
#         'url': 'https://www.grubhub.com/restaurant/manhattan-in-the-desert--2665-e-palm-canyon-dr--palm-springs/343682?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=343682',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ad24911f964a520b1e020e3-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b3a85a1f964a520406925e3',
#        'name': 'Native Foods',
#        'location': {'address': '1775 East Palm Canyon Drive',
#         'lat': 33.800009391990486,
#         'lng': -116.52743553961452,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.800009391990486,
#           'lng': -116.52743553961452},
#          {'label': 'entrance', 'lat': 33.80014, 'lng': -116.527616}],
#         'distance': 2350,
#         'postalCode': '92264',
#         'cc': 'US',
#         'city': 'Palm Springs',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1775 East Palm Canyon Drive',
#          'Palm Springs, CA 92264',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d3941735',
#          'name': 'Vegetarian / Vegan Restaurant',
#          'pluralName': 'Vegetarian / Vegan Restaurants',
#          'shortName': 'Vegetarian / Vegan',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '547075',
#         'url': 'https://www.grubhub.com/restaurant/native-foods-1775-e-palm-canyon-dr-palm-springs/547075?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=547075',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b3a85a1f964a520406925e3-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b521ecbf964a520876927e3',
#        'name': 'Tahquitz Creek Golf Course',
#        'location': {'address': '1885 Golf Club Dr',
#         'lat': 33.801130801064154,
#         'lng': -116.48506339972974,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.801130801064154,
#           'lng': -116.48506339972974}],
#         'distance': 1909,
#         'postalCode': '92264',
#         'cc': 'US',
#         'city': 'Palm Springs',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1885 Golf Club Dr',
#          'Palm Springs, CA 92264',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e6941735',
#          'name': 'Golf Course',
#          'pluralName': 'Golf Courses',
#          'shortName': 'Golf Course',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/golfcourse_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '46532897'}},
#       'referralId': 'e-0-4b521ecbf964a520876927e3-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b719f05f964a520ab512de3',
#        'name': "Jensen's Finest Foods",
#        'location': {'address': '2465 E Palm Canyon Dr Bldg 7',
#         'lat': 33.79977920177332,
#         'lng': -116.52216082036978,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.79977920177332,
#           'lng': -116.52216082036978},
#          {'label': 'entrance', 'lat': 33.801117, 'lng': -116.521833}],
#         'distance': 1884,
#         'postalCode': '92264',
#         'cc': 'US',
#         'city': 'Palm Springs',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['2465 E Palm Canyon Dr Bldg 7',
#          'Palm Springs, CA 92264',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b719f05f964a520ab512de3-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fd39669e4b0cb311ed5058c',
#        'name': 'The Saguaro Poolside',
#        'location': {'lat': 33.802189365599745,
#         'lng': -116.52697627664452,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.802189365599745,
#           'lng': -116.52697627664452}],
#         'distance': 2400,
#         'postalCode': '92264',
#         'cc': 'US',
#         'city': 'Palm Springs',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['Palm Springs, CA 92264', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d15e941735',
#          'name': 'Pool',
#          'pluralName': 'Pools',
#          'shortName': 'Pool',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fd39669e4b0cb311ed5058c-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f0f7f4ad5fb0e64b14375b6',
#        'name': 'Over the Rainbow Desserts',
#        'location': {'address': '1775 E Palm Canyon Dr, Ste 150',
#         'lat': 33.800095327823094,
#         'lng': -116.52713215386017,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.800095327823094,
#           'lng': -116.52713215386017},
#          {'label': 'entrance', 'lat': 33.80014, 'lng': -116.527616}],
#         'distance': 2326,
#         'postalCode': '92264',
#         'cc': 'US',
#         'city': 'Palm Springs',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1775 E Palm Canyon Dr, Ste 150',
#          'Palm Springs, CA 92264',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1bc941735',
#          'name': 'Cupcake Shop',
#          'pluralName': 'Cupcake Shops',
#          'shortName': 'Cupcakes',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cupcakes_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '51821129'}},
#       'referralId': 'e-0-4f0f7f4ad5fb0e64b14375b6-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50fe1e94e4b07b833d325226',
#        'name': 'Sparrows Lodge',
#        'location': {'address': '1330 E Palm Canyon Dr',
#         'crossStreet': 'Driftwood Dr',
#         'lat': 33.801901,
#         'lng': -116.532388,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.801901,
#           'lng': -116.532388}],
#         'distance': 2852,
#         'postalCode': '92264',
#         'cc': 'US',
#         'city': 'Palm Springs',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1330 E Palm Canyon Dr (Driftwood Dr)',
#          'Palm Springs, CA 92264',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50fe1e94e4b07b833d325226-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b719554f964a5200c4f2de3',
#        'name': 'Smart & Final Extra!',
#        'location': {'address': '5001 Ramon Road Bldg. 4',
#         'lat': 33.81451106008165,
#         'lng': -116.49170986180994,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.81451106008165,
#           'lng': -116.49170986180994}],
#         'distance': 2604,
#         'postalCode': '92264',
#         'cc': 'US',
#         'city': 'Palm Springs',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['5001 Ramon Road Bldg. 4',
#          'Palm Springs, CA 92264',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b719554f964a5200c4f2de3-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c448987f799e21e1ff4ada2',
#        'name': "Rubio's",
#        'location': {'address': '5200 Ramon Rd,',
#         'crossStreet': 'Gene Autry Trl',
#         'lat': 33.816741,
#         'lng': -116.492387,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.816741,
#           'lng': -116.492387},
#          {'label': 'entrance', 'lat': 33.816637, 'lng': -116.491211}],
#         'distance': 2809,
#         'postalCode': '92264',
#         'cc': 'US',
#         'city': 'Palm Springs',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['5200 Ramon Rd, (Gene Autry Trl)',
#          'Palm Springs, CA 92264',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ce941735',
#          'name': 'Seafood Restaurant',
#          'pluralName': 'Seafood Restaurants',
#          'shortName': 'Seafood',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '385830',
#         'url': 'https://www.grubhub.com/restaurant/rubios-coastal-grill-5200-ramon-rd-palm-springs/385830?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=385830',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '1359151349'}},
#       'referralId': 'e-0-4c448987f799e21e1ff4ada2-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc899dc92b376b043bd513a',
#        'name': 'Cree estate',
#        'location': {'address': '67698 Carey Rd',
#         'lat': 33.791891619168844,
#         'lng': -116.4803008877529,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.791891619168844,
#           'lng': -116.4803008877529}],
#         'distance': 2140,
#         'postalCode': '92234',
#         'cc': 'US',
#         'city': 'Cathedral City',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['67698 Carey Rd',
#          'Cathedral City, CA 92234',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d165941735',
#          'name': 'Scenic Lookout',
#          'pluralName': 'Scenic Lookouts',
#          'shortName': 'Scenic Lookout',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/sceniclookout_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bc899dc92b376b043bd513a-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d913fb93dd4a093132e7718',
#        'name': 'Studio M Salon and Spa',
#        'location': {'address': '2465 E Palm Canyon Dr Ste 1025',
#         'crossStreet': 'Farrell',
#         'lat': 33.8009392,
#         'lng': -116.5212327,
#         'labeledLatLngs': [{'label': 'entrance',
#           'lat': 33.801117,
#           'lng': -116.521833},
#          {'label': 'display', 'lat': 33.8009392, 'lng': -116.5212327}],
#         'distance': 1861,
#         'postalCode': '92264',
#         'cc': 'US',
#         'city': 'Palm Springs',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['2465 E Palm Canyon Dr Ste 1025 (Farrell)',
#          'Palm Springs, CA 92264',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ed941735',
#          'name': 'Spa',
#          'pluralName': 'Spas',
#          'shortName': 'Spa',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d913fb93dd4a093132e7718-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '594046daa92d986a0a8e6039',
#        'name': "Chef Tanya's Kitchen",
#        'location': {'lat': 33.81179,
#         'lng': -116.49386,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.81179,
#           'lng': -116.49386}],
#         'distance': 2247,
#         'postalCode': '92264',
#         'cc': 'US',
#         'city': 'Palm Springs',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['Palm Springs, CA 92264', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d3941735',
#          'name': 'Vegetarian / Vegan Restaurant',
#          'pluralName': 'Vegetarian / Vegan Restaurants',
#          'shortName': 'Vegetarian / Vegan',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-594046daa92d986a0a8e6039-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4be5b697d4f7c9b6b7cc2520',
#        'name': 'Cost Plus World Market',
#        'location': {'address': '2465 E Palm Canyon Dr Bldg 4',
#         'lat': 33.79971365956988,
#         'lng': -116.52098345521316,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.79971365956988,
#           'lng': -116.52098345521316},
#          {'label': 'entrance', 'lat': 33.801117, 'lng': -116.521833}],
#         'distance': 1781,
#         'postalCode': '92264',
#         'cc': 'US',
#         'city': 'Palm Springs',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['2465 E Palm Canyon Dr Bldg 4',
#          'Palm Springs, CA 92264',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1f8941735',
#          'name': 'Furniture / Home Store',
#          'pluralName': 'Furniture / Home Stores',
#          'shortName': 'Furniture / Home',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/furniture_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4be5b697d4f7c9b6b7cc2520-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ef0f155490178f61cbb460b',
#        'name': 'The Saguaro Palm Springs',
#        'location': {'address': '1800 E Palm Canyon Dr',
#         'crossStreet': 'at S Sunrise Way',
#         'lat': 33.802235,
#         'lng': -116.527104,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.802235,
#           'lng': -116.527104}],
#         'distance': 2413,
#         'postalCode': '92264',
#         'cc': 'US',
#         'city': 'Palm Springs',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1800 E Palm Canyon Dr (at S Sunrise Way)',
#          'Palm Springs, CA 92264',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '66857882'}},
#       'referralId': 'e-0-4ef0f155490178f61cbb460b-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b103775f964a520916b23e3',
#        'name': 'Smoke Tree Ranch',
#        'location': {'address': '1850 Smoke Tree Ln',
#         'lat': 33.796767884555955,
#         'lng': -116.52619085836723,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.796767884555955,
#           'lng': -116.52619085836723}],
#         'distance': 2146,
#         'postalCode': '92264',
#         'cc': 'US',
#         'city': 'Palm Springs',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1850 Smoke Tree Ln',
#          'Palm Springs, CA 92264',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d12f951735',
#          'name': 'Resort',
#          'pluralName': 'Resorts',
#          'shortName': 'Resort',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/resort_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b103775f964a520916b23e3-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dcf5db6fa7664b7c6c0a656',
#        'name': "Giuseppe's Pizzeria",
#        'location': {'address': '1775 E Palm Canyon Dr. Suite 410',
#         'lat': 33.80002449391938,
#         'lng': -116.52758882907987,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.80002449391938,
#           'lng': -116.52758882907987},
#          {'label': 'entrance', 'lat': 33.80014, 'lng': -116.527616}],
#         'distance': 2364,
#         'postalCode': '92264',
#         'cc': 'US',
#         'city': 'Palm Springs',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1775 E Palm Canyon Dr. Suite 410',
#          'Palm Springs, CA 92264',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '34679404'}},
#       'referralId': 'e-0-4dcf5db6fa7664b7c6c0a656-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bccc69468f976b02e3f6383',
#        'name': 'La Perlita',
#        'location': {'address': '901 Crossley Rd',
#         'crossStreet': 'btwn E Ramon Rd  & Dinah Shore Dr',
#         'lat': 33.81101258155805,
#         'lng': -116.48492151726768,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.81101258155805,
#           'lng': -116.48492151726768},
#          {'label': 'entrance', 'lat': 33.810791, 'lng': -116.484818}],
#         'distance': 2615,
#         'postalCode': '92264',
#         'cc': 'US',
#         'city': 'Palm Springs',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['901 Crossley Rd (btwn E Ramon Rd  & Dinah Shore Dr)',
#          'Palm Springs, CA 92264',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c1941735',
#          'name': 'Mexican Restaurant',
#          'pluralName': 'Mexican Restaurants',
#          'shortName': 'Mexican',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bccc69468f976b02e3f6383-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bd1c8b9046076b0e8717271',
#        'name': 'Indian Canyons Golf Resort',
#        'location': {'address': '1097 E Murray Canyon Dr',
#         'lat': 33.783353727597316,
#         'lng': -116.53456099519214,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.783353727597316,
#           'lng': -116.53456099519214}],
#         'distance': 3086,
#         'postalCode': '92264',
#         'cc': 'US',
#         'city': 'Palm Springs',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1097 E Murray Canyon Dr',
#          'Palm Springs, CA 92264',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e6941735',
#          'name': 'Golf Course',
#          'pluralName': 'Golf Courses',
#          'shortName': 'Golf Course',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/golfcourse_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bd1c8b9046076b0e8717271-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55b67722498e842f2ed32222',
#        'name': "L'Horizon Resort & Spa",
#        'location': {'address': '1050 E Palm Canyon Dr',
#         'crossStreet': 'Deep well',
#         'lat': 33.801581774844166,
#         'lng': -116.53532342199685,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.801581774844166,
#           'lng': -116.53532342199685}],
#         'distance': 3098,
#         'postalCode': '92264',
#         'cc': 'US',
#         'city': 'Palm Springs',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1050 E Palm Canyon Dr (Deep well)',
#          'Palm Springs, CA 92264',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55b67722498e842f2ed32222-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ba91ab0f964a520a40b3ae3',
#        'name': 'Aspen Mills Bakery & Bread Company',
#        'location': {'address': '555 S Sunrise Way',
#         'lat': 33.81541229716934,
#         'lng': -116.52885104792752,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.81541229716934,
#           'lng': -116.52885104792752},
#          {'label': 'entrance', 'lat': 33.814977, 'lng': -116.528771}],
#         'distance': 3413,
#         'postalCode': '92264',
#         'cc': 'US',
#         'city': 'Palm Springs',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['555 S Sunrise Way',
#          'Palm Springs, CA 92264',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'shortName': 'Sandwiches',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '460381282'}},
#       'referralId': 'e-0-4ba91ab0f964a520a40b3ae3-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b4e8a16f964a520e3f026e3',
#        'name': 'Upper Crust Pizza',
#        'location': {'address': '67555 E Palm Canyon Dr',
#         'crossStreet': 'Dunton Wy',
#         'lat': 33.787658641582006,
#         'lng': -116.48142950247907,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.787658641582006,
#           'lng': -116.48142950247907}],
#         'distance': 2123,
#         'postalCode': '92234',
#         'cc': 'US',
#         'city': 'Cathedral City',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['67555 E Palm Canyon Dr (Dunton Wy)',
#          'Cathedral City, CA 92234',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b4e8a16f964a520e3f026e3-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54d408f0498e4103824f11ed',
#        'name': 'EOS Fitness - Palm Springs',
#        'location': {'address': '4070 Airport Center Dr',
#         'lat': 33.81704314712103,
#         'lng': -116.50189604165791,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.81704314712103,
#           'lng': -116.50189604165791}],
#         'distance': 2655,
#         'postalCode': '92264',
#         'cc': 'US',
#         'city': 'Palm Springs',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['4070 Airport Center Dr',
#          'Palm Springs, CA 92264',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'shortName': 'Gym',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54d408f0498e4103824f11ed-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e98ded09adffd1f47440950',
#        'name': 'Purple Room',
#        'location': {'address': '1900 E Palm Canyon Dr',
#         'lat': 33.80176741975854,
#         'lng': -116.52562692320318,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.80176741975854,
#           'lng': -116.52562692320318},
#          {'label': 'entrance', 'lat': 33.801807, 'lng': -116.525903}],
#         'distance': 2267,
#         'postalCode': '92264',
#         'cc': 'US',
#         'city': 'Palm Springs',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1900 E Palm Canyon Dr',
#          'Palm Springs, CA 92264',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '66015904'}},
#       'referralId': 'e-0-4e98ded09adffd1f47440950-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c571afacc96c9b64035782e',
#        'name': 'Panda Express',
#        'location': {'address': '5200 E Ramon Rd',
#         'lat': 33.81631546039022,
#         'lng': -116.49191860458102,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.81631546039022,
#           'lng': -116.49191860458102},
#          {'label': 'entrance', 'lat': 33.816637, 'lng': -116.491211}],
#         'distance': 2781,
#         'postalCode': '92264',
#         'cc': 'US',
#         'city': 'Palm Springs',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['5200 E Ramon Rd',
#          'Palm Springs, CA 92264',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1958180',
#         'url': 'https://www.grubhub.com/restaurant/panda-express-5200-ramon-rd-palm-springs/1958180?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1958180',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c571afacc96c9b64035782e-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ae8ea37f964a5204cb321e3',
#        'name': 'Ace Hotel & Swim Club',
#        'location': {'address': '701 E Palm Canyon Dr',
#         'crossStreet': 'at Indian Trl.',
#         'lat': 33.80095023514467,
#         'lng': -116.53987427963307,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.80095023514467,
#           'lng': -116.53987427963307}],
#         'distance': 3483,
#         'postalCode': '92264',
#         'cc': 'US',
#         'city': 'Palm Springs',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['701 E Palm Canyon Dr (at Indian Trl.)',
#          'Palm Springs, CA 92264',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ae8ea37f964a5204cb321e3-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5335d2e4498e497bb5007d22',
#        'name': "Wet'n'Wild Palm Springs",
#        'location': {'address': '1500 S Gene Autry Trl',
#         'lat': 33.804659646108824,
#         'lng': -116.49082520908543,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.804659646108824,
#           'lng': -116.49082520908543}],
#         'distance': 1723,
#         'postalCode': '92264',
#         'cc': 'US',
#         'city': 'Palm Springs',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1500 S Gene Autry Trl',
#          'Palm Springs, CA 92264',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d193941735',
#          'name': 'Water Park',
#          'pluralName': 'Water Parks',
#          'shortName': 'Water Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/waterpark_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5335d2e4498e497bb5007d22-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b53bbeaf964a520a1a927e3',
#        'name': "Nature's Health Food & Cafe",
#        'location': {'address': '555 S Sunrise Way #301',
#         'crossStreet': 'btwn Escanaba & E Ramon',
#         'lat': 33.81427247683018,
#         'lng': -116.52856436689707,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.81427247683018,
#           'lng': -116.52856436689707},
#          {'label': 'entrance', 'lat': 33.814977, 'lng': -116.528771}],
#         'distance': 3304,
#         'postalCode': '92264',
#         'cc': 'US',
#         'city': 'Palm Springs',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['555 S Sunrise Way #301 (btwn Escanaba & E Ramon)',
#          'Palm Springs, CA 92264',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d3941735',
#          'name': 'Vegetarian / Vegan Restaurant',
#          'pluralName': 'Vegetarian / Vegan Restaurants',
#          'shortName': 'Vegetarian / Vegan',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '343679',
#         'url': 'https://www.grubhub.com/restaurant/natures-caf-555-s-sunrise-way-suite-301-palm-springs/343679?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=343679',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b53bbeaf964a520a1a927e3-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54cc4385498ed355df365955',
#        'name': 'Smoke Tree BBQ Bar & Grill',
#        'location': {'address': '1775 E Palm Canyon Blvd',
#         'lat': 33.79996555326516,
#         'lng': -116.52724651623073,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.79996555326516,
#           'lng': -116.52724651623073}],
#         'distance': 2332,
#         'postalCode': '92264',
#         'cc': 'US',
#         'city': 'Palm Springs',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1775 E Palm Canyon Blvd',
#          'Palm Springs, CA 92264',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1df931735',
#          'name': 'BBQ Joint',
#          'pluralName': 'BBQ Joints',
#          'shortName': 'BBQ',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2044076',
#         'url': 'https://www.grubhub.com/restaurant/smoke-tree-bbq-1775-e-palm-canyon-dr-suite-405-palm-springs/2044076?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2044076',
#         'provider': {'name': 'grubhub',
# ...
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c254c1dc11dc9b69a042724-87'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56f4a8da498e11dd57b866f9',
#        'name': 'ALDI',
#        'location': {'address': '5200 E Ramon Rd Ste B5',
#         'crossStreet': 'at Gene Autry Tr',
#         'lat': 33.818742464392095,
#         'lng': -116.49275841455322,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.818742464392095,
#           'lng': -116.49275841455322}],
#         'distance': 3006,
#         'postalCode': '92264',
#         'cc': 'US',
#         'city': 'Palm Springs',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['5200 E Ramon Rd Ste B5 (at Gene Autry Tr)',
#          'Palm Springs, CA 92264',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56f4a8da498e11dd57b866f9-88'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b9d862af964a520e1b136e3',
#        'name': 'Salsas Restaurant',
#        'location': {'address': '37100-37298 Date Palm Dr',
#         'crossStreet': '37100-37298 Date Palm Dr',
#         'lat': 33.7792622171004,
#         'lng': -116.45770456384693,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.7792622171004,
#           'lng': -116.45770456384693}],
#         'distance': 4502,
#         'postalCode': '92234',
#         'cc': 'US',
#         'city': 'Cathedral City',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['37100-37298 Date Palm Dr (37100-37298 Date Palm Dr)',
#          'Cathedral City, CA 92234',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c1941735',
#          'name': 'Mexican Restaurant',
#          'pluralName': 'Mexican Restaurants',
#          'shortName': 'Mexican',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b9d862af964a520e1b136e3-89'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b6cf4e9f964a52020602ce3',
#        'name': 'Cathedral Canyon Country Club',
#        'location': {'address': '34-567 Cathedral Canyon Dr',
#         'lat': 33.79524448058023,
#         'lng': -116.47022472163565,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.79524448058023,
#           'lng': -116.47022472163565}],
#         'distance': 3075,
#         'postalCode': '92234',
#         'cc': 'US',
#         'city': 'Cathedral City',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['34-567 Cathedral Canyon Dr',
#          'Cathedral City, CA 92234',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e6941735',
#          'name': 'Golf Course',
#          'pluralName': 'Golf Courses',
#          'shortName': 'Golf Course',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/golfcourse_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b6cf4e9f964a52020602ce3-90'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54bb2aac498e84e3e165b3e6',
#        'name': "Dickey's Barbecue Pit",
#        'location': {'address': '5200 E Ramon Rd',
#         'crossStreet': 'at Gene Autry Trl',
#         'lat': 33.81633094830076,
#         'lng': -116.49192740941572,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.81633094830076,
#           'lng': -116.49192740941572}],
#         'distance': 2782,
#         'postalCode': '92264',
#         'cc': 'US',
#         'city': 'Palm Springs',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['5200 E Ramon Rd (at Gene Autry Trl)',
#          'Palm Springs, CA 92264',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1df931735',
#          'name': 'BBQ Joint',
#          'pluralName': 'BBQ Joints',
#          'shortName': 'BBQ',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '343686',
#         'url': 'https://www.grubhub.com/restaurant/dickeys-barbecue-pit--5200-e-ramon-rd--palm-springs/343686?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=343686',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54bb2aac498e84e3e165b3e6-91'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b804c3af964a5207a6530e3',
#        'name': 'Palm Greens Café',
#        'location': {'address': '611 S Palm Canyon Dr',
#         'lat': 33.81366002003183,
#         'lng': -116.54682699132896,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.81366002003183,
#           'lng': -116.54682699132896},
#          {'label': 'entrance', 'lat': 33.813351, 'lng': -116.545366}],
#         'distance': 4618,
#         'postalCode': '92264',
#         'cc': 'US',
#         'city': 'Palm Springs',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['611 S Palm Canyon Dr',
#          'Palm Springs, CA 92264',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d3941735',
#          'name': 'Vegetarian / Vegan Restaurant',
#          'pluralName': 'Vegetarian / Vegan Restaurants',
#          'shortName': 'Vegetarian / Vegan',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b804c3af964a5207a6530e3-92'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b9da0a7f964a52007b736e3',
#        'name': 'Starbucks',
#        'location': {'address': '682 S Palm Canyon Dr',
#         'lat': 33.81279683561571,
#         'lng': -116.54447610925209,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.81279683561571,
#           'lng': -116.54447610925209},
#          {'label': 'entrance', 'lat': 33.812801, 'lng': -116.544499}],
#         'distance': 4381,
#         'postalCode': '92264',
#         'cc': 'US',
#         'city': 'Palm Springs',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['682 S Palm Canyon Dr',
#          'Palm Springs, CA 92264',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b9da0a7f964a52007b736e3-93'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b6506a6f964a52029e02ae3',
#        'name': 'El Mirasol Regional Cuisines',
#        'location': {'address': '140 E Palm Canyon Dr',
#         'crossStreet': 'at Ave Olancha',
#         'lat': 33.802778863719325,
#         'lng': -116.54540784387046,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.802778863719325,
#           'lng': -116.54540784387046}],
#         'distance': 4030,
#         'postalCode': '92264',
#         'cc': 'US',
#         'city': 'Palm Springs',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['140 E Palm Canyon Dr (at Ave Olancha)',
#          'Palm Springs, CA 92264',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c1941735',
#          'name': 'Mexican Restaurant',
#          'pluralName': 'Mexican Restaurants',
#          'shortName': 'Mexican',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b6506a6f964a52029e02ae3-94'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a4d5135b2958f73b4211f50',
#        'name': 'Ulta Beauty',
#        'location': {'address': '5200 E Ramon Rd',
#         'lat': 33.8166177,
#         'lng': -116.4912304,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.8166177,
#           'lng': -116.4912304}],
#         'distance': 2837,
#         'postalCode': '92264',
#         'cc': 'US',
#         'city': 'Palm Springs',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['5200 E Ramon Rd',
#          'Palm Springs, CA 92264',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d10c951735',
#          'name': 'Cosmetics Shop',
#          'pluralName': 'Cosmetics Shops',
#          'shortName': 'Cosmetics',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/beauty_cosmetic_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5a4d5135b2958f73b4211f50-95'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dac898d43a1128197289c0b',
#        'name': 'La Carreta Taco Shop',
#        'location': {'address': '67555 E Palm Canyon Dr',
#         'lat': 33.788651795737216,
#         'lng': -116.48353488815647,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.788651795737216,
#           'lng': -116.48353488815647}],
#         'distance': 1905,
#         'postalCode': '92234',
#         'cc': 'US',
#         'city': 'Cathedral City',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['67555 E Palm Canyon Dr',
#          'Cathedral City, CA 92234',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d151941735',
#          'name': 'Taco Place',
#          'pluralName': 'Taco Places',
#          'shortName': 'Tacos',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/taco_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dac898d43a1128197289c0b-96'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b5954f0f964a5204f8528e3',
#        'name': "Shanghai Red's Oyster Bar",
#        'location': {'address': '235 S Indian Canyon Dr',
#         'crossStreet': 'btw Baristo & Arenas',
#         'lat': 33.82055220042925,
#         'lng': -116.54603334200047,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.82055220042925,
#           'lng': -116.54603334200047}],
#         'distance': 4982,
#         'postalCode': '92262',
#         'cc': 'US',
#         'city': 'Palm Springs',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['235 S Indian Canyon Dr (btw Baristo & Arenas)',
#          'Palm Springs, CA 92262',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ce941735',
#          'name': 'Seafood Restaurant',
#          'pluralName': 'Seafood Restaurants',
#          'shortName': 'Seafood',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b5954f0f964a5204f8528e3-97'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55764e61498ef374656bf01b',
#        'name': "Wang's Chinese Cuisine",
#        'location': {'address': '35300 Date Palm Dr',
#         'lat': 33.79192190917173,
#         'lng': -116.45776248211317,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.79192190917173,
#           'lng': -116.45776248211317}],
#         'distance': 4222,
#         'postalCode': '92234',
#         'cc': 'US',
#         'city': 'Cathedral City',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['35300 Date Palm Dr',
#          'Cathedral City, CA 92234',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'shortName': 'Asian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '801090',
#         'url': 'https://www.grubhub.com/restaurant/wangs-chinese-cuisine-35300-date-palm-dr-cathedral-city/801090?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=801090',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55764e61498ef374656bf01b-98'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bd4a7a529eb9c74421592e1',
#        'name': 'Palm Springs Dog Park',
#        'location': {'address': '222 Civic Dr.',
#         'lat': 33.82499424229546,
#         'lng': -116.51236496489538,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.82499424229546,
#           'lng': -116.51236496489538}],
#         'distance': 3633,
#         'postalCode': '92262',
#         'cc': 'US',
#         'city': 'Palm Springs',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['222 Civic Dr.',
#          'Palm Springs, CA 92262',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e5941735',
#          'name': 'Dog Run',
#          'pluralName': 'Dog Runs',
#          'shortName': 'Dog Run',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/dogrun_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bd4a7a529eb9c74421592e1-99'}]}]}}

# %% [markdown]
# ## Now we create a function of get the type of categories of the venues

# %%
# Let's now extract the categories of the venues
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %% [markdown]
# ## We use the results matrix to get the list of nearby venues

# %%
venues = results['response']['groups'][0]['items']
    
SGnearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
SGnearby_venues =SGnearby_venues.loc[:, filtered_columns]

# filter the category for each row
SGnearby_venues['venue.categories'] = SGnearby_venues.apply(get_category_type, axis=1)

# clean columns
SGnearby_venues.columns = [col.split(".")[-1] for col in SGnearby_venues.columns]

SGnearby_venues.head(20)
# Out:
#                           name                     categories        lat  \
# 0                     PSYC Spa                            Spa  33.795558
# 1                      Norma's                 Breakfast Spot  33.795451
# 2      The Parker Palm Springs                          Hotel  33.795264
# 3               Lemonade Stand                     Restaurant  33.796288
# 4          Counter Reformation                      Speakeasy  33.795369
# 5                 Trader Joe's                  Grocery Store  33.789218
# 6                    T.J. Maxx               Department Store  33.799686
# 7       Chipotle Mexican Grill             Mexican Restaurant  33.800772
# 8      Manhattan In The Desert                 Sandwich Place  33.800954
# 9                 Native Foods  Vegetarian / Vegan Restaurant  33.800009
# 10  Tahquitz Creek Golf Course                    Golf Course  33.801131
# 11       Jensen's Finest Foods                  Grocery Store  33.799779
# 12        The Saguaro Poolside                           Pool  33.802189
# 13   Over the Rainbow Desserts                   Cupcake Shop  33.800095
# 14              Sparrows Lodge                          Hotel  33.801901
# 15        Smart & Final Extra!                  Grocery Store  33.814511
# 16                     Rubio's             Seafood Restaurant  33.816741
# 17                 Cree estate                 Scenic Lookout  33.791892
# 18      Studio M Salon and Spa                            Spa  33.800939
# 19        Chef Tanya's Kitchen  Vegetarian / Vegan Restaurant  33.811790
#
#            lng
# 0  -116.500941
# 1  -116.500269
# 2  -116.500204
# 3  -116.500791
# 4  -116.500292
# 5  -116.483060
# 6  -116.520140
# 7  -116.521676
# 8  -116.518154
# 9  -116.527436
# 10 -116.485063
# 11 -116.522161
# 12 -116.526976
# 13 -116.527132
# 14 -116.532388
# 15 -116.491710
# 16 -116.492387
# 17 -116.480301
# 18 -116.521233
# 19 -116.493860

# %% [markdown]
# ## Let us now generate a map of Santa Monica City Center and nearby venues

# %%
# create map of Santa Monica's Energy City Center using latitude and longitude values
map_sg = folium.Map(location=[latitude, longitude], zoom_start=14)

# add markers to map
for lat, lng, label in zip(SGnearby_venues['lat'], SGnearby_venues['lng'], SGnearby_venues['name']):
    label = folium.Popup(label, parse_html=True)
    folium.RegularPolygonMarker(
        [lat, lng],
        number_of_sides=4,
        radius=10,
        popup=label,
        color='blue',
        fill_color='#0f0f0f',
        fill_opacity=0.7,
    ).add_to(map_sg)  
    
map_sg
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Count the types of venues in each category to understand what is the current competition

# %%
SGnearby_venues['categories'].value_counts()
# Out:
# Mexican Restaurant               9
# Hotel                            6
# Sandwich Place                   5
# Spa                              4
# Grocery Store                    4
# Vegetarian / Vegan Restaurant    4
# Resort                           3
# Golf Course                      3
# Breakfast Spot                   3
# Coffee Shop                      3
# Pool                             3
# Cocktail Bar                     2
# Seafood Restaurant               2
# Restaurant                       2
# BBQ Joint                        2
# Cosmetics Shop                   2
# Furniture / Home Store           2
# Deli / Bodega                    2
# Burger Joint                     2
# Gym                              2
# American Restaurant              2
# Gay Bar                          2
# Trail                            2
# Chinese Restaurant               2
# Ice Cream Shop                   1
# Cupcake Shop                     1
# Pizza Place                      1
# Steakhouse                       1
# Scenic Lookout                   1
# Pet Store                        1
# Thrift / Vintage Store           1
# Bagel Shop                       1
# Hardware Store                   1
# Italian Restaurant               1
# Garden                           1
# Juice Bar                        1
# Big Box Store                    1
# Water Park                       1
# Pharmacy                         1
# Speakeasy                        1
# Supermarket                      1
# Donut Shop                       1
# Dog Run                          1
# Bakery                           1
# Taco Place                       1
# Indian Restaurant                1
# Hotel Bar                        1
# Airport                          1
# Museum                           1
# Asian Restaurant                 1
# Department Store                 1
# Name: categories, dtype: int64

# %% [markdown]
# ## Count the names of venues (this time) to understand what franchises already exist in the area

# %%
SGnearby_venues['name'].value_counts()
# Out:
# Starbucks                                                                        2
# Studio One 11                                                                    1
# Indian Canyons Golf Resort                                                       1
# Panda Express                                                                    1
# The Home Depot                                                                   1
# El Portal                                                                        1
# Monsoon Indian Cuisine                                                           1
# Counter Reformation                                                              1
# Massage Envy - Palm Springs                                                      1
# Tahquitz Creek Golf Course                                                       1
# Salsas Restaurant                                                                1
# La Carreta Taco Shop                                                             1
# T.J. Maxx                                                                        1
# Swiss Donut                                                                      1
# Kreem                                                                            1
# Chef Tanya's Kitchen                                                             1
# Smoke Tree BBQ Bar & Grill                                                       1
# Cree estate                                                                      1
# PSYC Spa                                                                         1
# The Oasis Resort                                                                 1
# Jensen's Finest Foods                                                            1
# The Real Italian Deli of Palm Springs                                            1
# Ulta Beauty                                                                      1
# Wet'n'Wild Palm Springs                                                          1
# Lemonade Stand                                                                   1
# Smokin' Burgers & Lounge                                                         1
# L'Horizon Resort & Spa                                                           1
# Manhattan In The Desert                                                          1
# The Saguaro Palm Springs                                                         1
# King's Highway                                                                   1
# Trader Joe's                                                                     1
# Mr. Lyons                                                                        1
# Palm Springs Dog Park                                                            1
# Cost Plus World Market                                                           1
# Delight Nails & Spa                                                              1
# Felipe's                                                                         1
# La Tablita                                                                       1
# Tony's Burgers                                                                   1
# The Parker Palm Springs                                                          1
# EOS Fitness - Palm Springs                                                       1
# Palm Springs Air Museum                                                          1
# Tool Shed                                                                        1
# Jersey Mike's Subs                                                               1
# Ace Hotel Feel Good Spa                                                          1
# PetSmart                                                                         1
# Ralphs                                                                           1
# Wang's Chinese Cuisine                                                           1
# Upper Crust Pizza                                                                1
# South Lykken Trail Palm Springs                                                  1
# Villa Bakery                                                                     1
# Desert Riviera Hotel                                                             1
# Chipotle Mexican Grill                                                           1
# Elmer’s Restaurant                                                               1
# Moorten Botanical Garden                                                         1
# The Amigo Room                                                                   1
# New Fortune                                                                      1
# Michaels Cafe                                                                    1
# Rubio's                                                                          1
# El Mirasol Regional Cuisines                                                     1
# Koffi                                                                            1
# Palm Springs Ftness                                                              1
# Nature's Health Food & Cafe                                                      1
# Native Foods                                                                     1
# Walgreens                                                                        1
# Smart & Final Extra!                                                             1
# Purple Room                                                                      1
# Bed Bath & Beyond                                                                1
# Palm Greens Café                                                                 1
# The Wesley Palm Springs                                                          1
# The Saguaro Poolside                                                             1
# El Jefe                                                                          1
# Aspen Mills Bakery & Bread Company                                               1
# Giuseppe's Pizzeria                                                              1
# La Perlita                                                                       1
# ALDI                                                                             1
# Dickey's Barbecue Pit                                                            1
# Sparrows Lodge                                                                   1
# Goodwill                                                                         1
# Sunshine Cafe                                                                    1
# Panera Bread                                                                     1
# Ace Hotel & Swim Club Lounge                                                     1
# Over the Rainbow Desserts                                                        1
# SUBWAY                                                                           1
# Seymour's                                                                        1
# Indian Canyons                                                                   1
# Shanghai Red's Oyster Bar                                                        1
# Norma's                                                                          1
# Sherman's Deli & Bakery                                                          1
# Townie Bagels                                                                    1
# Cathedral Canyon Country Club                                                    1
# Palm Springs Swim Center                                                         1
# Ace Hotel & Swim Club                                                            1
# Palm Springs International Airport (PSP) (Palm Springs International Airport)    1
# Swim Club @ Ace Hotel                                                            1
# Smoke Tree Ranch                                                                 1
# Fresh Juice Bar                                                                  1
# Firehouse Subs                                                                   1
# Studio M Salon and Spa                                                           1
# Target                                                                           1
# Name: name, dtype: int64

# %%
SGnearby_venues['name']
# Out:
# 0                                              PSYC Spa
# 1                                               Norma's
# 2                               The Parker Palm Springs
# 3                                        Lemonade Stand
# 4                                   Counter Reformation
# 5                                          Trader Joe's
# 6                                             T.J. Maxx
# 7                                Chipotle Mexican Grill
# 8                               Manhattan In The Desert
# 9                                          Native Foods
# 10                           Tahquitz Creek Golf Course
# 11                                Jensen's Finest Foods
# 12                                 The Saguaro Poolside
# 13                            Over the Rainbow Desserts
# 14                                       Sparrows Lodge
# 15                                 Smart & Final Extra!
# 16                                              Rubio's
# 17                                          Cree estate
# 18                               Studio M Salon and Spa
# 19                                 Chef Tanya's Kitchen
# 20                               Cost Plus World Market
# 21                             The Saguaro Palm Springs
# 22                                     Smoke Tree Ranch
# 23                                  Giuseppe's Pizzeria
# 24                                           La Perlita
# 25                           Indian Canyons Golf Resort
# 26                               L'Horizon Resort & Spa
# 27                   Aspen Mills Bakery & Bread Company
# 28                                    Upper Crust Pizza
# 29                           EOS Fitness - Palm Springs
# 30                                          Purple Room
# 31                                        Panda Express
# 32                                Ace Hotel & Swim Club
# 33                              Wet'n'Wild Palm Springs
# 34                          Nature's Health Food & Cafe
# 35                           Smoke Tree BBQ Bar & Grill
# 36                                        Sunshine Cafe
# 37                                             Goodwill
# 38                                          New Fortune
# 39                                Swim Club @ Ace Hotel
# 40                                              El Jefe
# 41                                            Walgreens
# 42                                             PetSmart
# 43                                                Koffi
# 44                                               Target
# 45                                   Elmer’s Restaurant
# 46                                               Ralphs
# 47                                       The Home Depot
# 48                             Palm Springs Swim Center
# 49                                                Kreem
# 50                                     The Oasis Resort
# 51    Palm Springs International Airport (PSP) (Palm...
# 52                                  Delight Nails & Spa
# 53                The Real Italian Deli of Palm Springs
# 54                                 Desert Riviera Hotel
# 55                                       The Amigo Room
# 56                                            Seymour's
# 57                                        Studio One 11
# 58                                           La Tablita
# 59                                       Indian Canyons
# 60                              Palm Springs Air Museum
# 61                      South Lykken Trail Palm Springs
# 62                                        Townie Bagels
# 63                                         Villa Bakery
# 64                                       Tony's Burgers
# 65                                   Jersey Mike's Subs
# 66                             Smokin' Burgers & Lounge
# 67                                       Firehouse Subs
# 68                                       King's Highway
# 69                                      Fresh Juice Bar
# 70                                          Swiss Donut
# 71                         Ace Hotel & Swim Club Lounge
# 72                          Massage Envy - Palm Springs
# 73                              The Wesley Palm Springs
# 74                             Moorten Botanical Garden
# 75                                            Starbucks
# 76                               Monsoon Indian Cuisine
# 77                                            Mr. Lyons
# 78                                         Panera Bread
# 79                                            El Portal
# 80                              Sherman's Deli & Bakery
# 81                              Ace Hotel Feel Good Spa
# 82                                    Bed Bath & Beyond
# 83                                               SUBWAY
# 84                                  Palm Springs Ftness
# 85                                            Tool Shed
# 86                                             Felipe's
# 87                                        Michaels Cafe
# 88                                                 ALDI
# 89                                    Salsas Restaurant
# 90                        Cathedral Canyon Country Club
# 91                                Dickey's Barbecue Pit
# 92                                     Palm Greens Café
# 93                                            Starbucks
# 94                         El Mirasol Regional Cuisines
# 95                                          Ulta Beauty
# 96                                 La Carreta Taco Shop
# 97                            Shanghai Red's Oyster Bar
# 98                               Wang's Chinese Cuisine
# 99                                Palm Springs Dog Park
# Name: name, dtype: object
